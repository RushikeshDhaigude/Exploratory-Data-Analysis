# %% [markdown]
# ## Housing Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Shree\Desktop\DS PROJECTS\5. London Housing Data.csv")

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0       1/1/1995  city of london          91449  E09000001         17.0
# 1       2/1/1995  city of london          82203  E09000001          7.0
# 2       3/1/1995  city of london          79121  E09000001         14.0
# 3       4/1/1995  city of london          77101  E09000001          7.0
# 4       5/1/1995  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544   9/1/2019         england         249942  E92000001      64605.0
# 13545  10/1/2019         england         249376  E92000001      68677.0
# 13546  11/1/2019         england         248515  E92000001      67814.0
# 13547  12/1/2019         england         250410  E92000001          NaN
# 13548   1/1/2020         england         247355  E92000001          NaN
#
#        no_of_crimes
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 13544           NaN
# 13545           NaN
# 13546           NaN
# 13547           NaN
# 13548           NaN
#
# [13549 rows x 6 columns]

# %%
data.describe()
# Out:
#        average_price    houses_sold  no_of_crimes
# count   1.354900e+04   13455.000000   7439.000000
# mean    2.635197e+05    3893.994129   2158.352063
# std     1.876175e+05   12114.402476    902.087742
# min     4.072200e+04       2.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000
# 50%     2.229190e+05     371.000000   2132.000000
# 75%     3.368430e+05    3146.000000   2582.000000
# max     1.463378e+06  132163.000000   7461.000000

# %%
data.value_counts()
# Out:
# date      area                    average_price  code       houses_sold  no_of_crimes
# 1/1/2001  barking and dagenham    82343          E09000002  215.0        1771.0          1
# 6/1/2001  kensington and chelsea  423411         E09000020  341.0        2149.0          1
#           hounslow                151510         E09000018  439.0        2384.0          1
#           hillingdon              142791         E09000017  460.0        2432.0          1
#           havering                122658         E09000016  404.0        1823.0          1
#                                                                                         ..
# 2/1/2001  hounslow                146554         E09000018  273.0        2108.0          1
#           hillingdon              138408         E09000017  274.0        2114.0          1
#           havering                117318         E09000016  302.0        1607.0          1
#           harrow                  160027         E09000015  272.0        1234.0          1
# 9/1/2019  westminster             925955         E09000033  169.0        6384.0          1
# Length: 7375, dtype: int64

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# ### Convert the Datatype of 'Date' column to Date-Time format.

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
# pd.to_datetime(df.Date_Time_Col) - Converts the data-type of Date-Time Column into datetime[ns] datatype.

# %%
data["date"]=pd.to_datetime(data["date"])

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# ### Add a new column ''year'' in the dataframe, which contains years only.
# ### Add a new column ''month'' as 2nd column in the dataframe, which contains month only.

# %%
# df[Time_Col].dt.year - Creating a new column with only year values
# df[Time_Col].dt.month - Creating a new column with only month values.

# %%
data.head(5)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
data["Year"]=data["date"].dt.year
data["Month"]=data["date"].dt.month

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  Year  Month
# 0               NaN  1995      1
# 1               NaN  1995      2
# 2               NaN  1995      3
# 3               NaN  1995      4
# 4               NaN  1995      5
# ...             ...   ...    ...
# 13544           NaN  2019      9
# 13545           NaN  2019     10
# 13546           NaN  2019     11
# 13547           NaN  2019     12
# 13548           NaN  2020      1
#
# [13549 rows x 8 columns]

# %%
# df.insert( column_index , ‘new_column_name’, new_column_values)
# To insert a New column at a particular position with values in it.

# %%
data.insert(1,"days",data["date"].dt.day)

# %%
data.insert(2,"ID",np.arange(13549))

# %%
data
# Out:
#             date  days     ID            area  average_price       code  \
# 0     1995-01-01     1      0  city of london          91449  E09000001
# 1     1995-02-01     1      1  city of london          82203  E09000001
# 2     1995-03-01     1      2  city of london          79121  E09000001
# 3     1995-04-01     1      3  city of london          77101  E09000001
# 4     1995-05-01     1      4  city of london          84409  E09000001
# ...          ...   ...    ...             ...            ...        ...
# 13544 2019-09-01     1  13544         england         249942  E92000001
# 13545 2019-10-01     1  13545         england         249376  E92000001
# 13546 2019-11-01     1  13546         england         248515  E92000001
# 13547 2019-12-01     1  13547         england         250410  E92000001
# 13548 2020-01-01     1  13548         england         247355  E92000001
#
#        houses_sold  no_of_crimes  Year  Month
# 0             17.0           NaN  1995      1
# 1              7.0           NaN  1995      2
# 2             14.0           NaN  1995      3
# 3              7.0           NaN  1995      4
# 4             10.0           NaN  1995      5
# ...            ...           ...   ...    ...
# 13544      64605.0           NaN  2019      9
# 13545      68677.0           NaN  2019     10
# 13546      67814.0           NaN  2019     11
# 13547          NaN           NaN  2019     12
# 13548          NaN           NaN  2020      1
#
# [13549 rows x 10 columns]

# %% [markdown]
# ### Remove the columns 'year' and 'month' from the dataframe.

# %%
# df.drop(columns=['Col_name'] , axis=1 , inplace = True) - To drop a column from the dataframe permanently.

# %%
data.head(5)
# Out:
#         date  days  ID            area  average_price       code  houses_sold  \
# 0 1995-01-01     1   0  city of london          91449  E09000001         17.0
# 1 1995-02-01     1   1  city of london          82203  E09000001          7.0
# 2 1995-03-01     1   2  city of london          79121  E09000001         14.0
# 3 1995-04-01     1   3  city of london          77101  E09000001          7.0
# 4 1995-05-01     1   4  city of london          84409  E09000001         10.0
#
#    no_of_crimes  Year  Month
# 0           NaN  1995      1
# 1           NaN  1995      2
# 2           NaN  1995      3
# 3           NaN  1995      4
# 4           NaN  1995      5

# %%
data.head(5)
# Out:
#         date  days  ID            area  average_price       code  houses_sold  \
# 0 1995-01-01     1   0  city of london          91449  E09000001         17.0
# 1 1995-02-01     1   1  city of london          82203  E09000001          7.0
# 2 1995-03-01     1   2  city of london          79121  E09000001         14.0
# 3 1995-04-01     1   3  city of london          77101  E09000001          7.0
# 4 1995-05-01     1   4  city of london          84409  E09000001         10.0
#
#    no_of_crimes  Year  Month
# 0           NaN  1995      1
# 1           NaN  1995      2
# 2           NaN  1995      3
# 3           NaN  1995      4
# 4           NaN  1995      5

# %%
data.drop(["days"],axis=1,inplace=True)

# %%
data.head(3)
# Out:
#         date  ID            area  average_price       code  houses_sold  \
# 0 1995-01-01   0  city of london          91449  E09000001         17.0
# 1 1995-02-01   1  city of london          82203  E09000001          7.0
# 2 1995-03-01   2  city of london          79121  E09000001         14.0
#
#    no_of_crimes  Year  Month
# 0           NaN  1995      1
# 1           NaN  1995      2
# 2           NaN  1995      3

# %% [markdown]
# ### Show all the records where 'No. of Crimes' is 0. And, how many such records are there ?

# %%
data["no_of_crimes"].value_counts()
# Out:
# 0.0       104
# 2039.0     11
# 1956.0     11
# 2276.0     10
# 2114.0     10
#          ...
# 1947.0      1
# 3493.0      1
# 3614.0      1
# 3241.0      1
# 6405.0      1
# Name: no_of_crimes, Length: 2669, dtype: int64

# %%
data[data["no_of_crimes"]==0]
# Out:
#           date   ID            area  average_price       code  houses_sold  \
# 72  2001-01-01   72  city of london         284262  E09000001         24.0
# 73  2001-02-01   73  city of london         198137  E09000001         37.0
# 74  2001-03-01   74  city of london         189033  E09000001         44.0
# 75  2001-04-01   75  city of london         205494  E09000001         38.0
# 76  2001-05-01   76  city of london         223459  E09000001         30.0
# ..         ...  ...             ...            ...        ...          ...
# 178 2009-11-01  178  city of london         397909  E09000001         11.0
# 179 2009-12-01  179  city of london         411955  E09000001         16.0
# 180 2010-01-01  180  city of london         464436  E09000001         20.0
# 181 2010-02-01  181  city of london         490525  E09000001          9.0
# 182 2010-03-01  182  city of london         498241  E09000001         15.0
#
#      no_of_crimes  Year  Month
# 72            0.0  2001      1
# 73            0.0  2001      2
# 74            0.0  2001      3
# 75            0.0  2001      4
# 76            0.0  2001      5
# ..            ...   ...    ...
# 178           0.0  2009     11
# 179           0.0  2009     12
# 180           0.0  2010      1
# 181           0.0  2010      2
# 182           0.0  2010      3
#
# [104 rows x 9 columns]

# %%
len(data[data["no_of_crimes"]==0])
# Out:
# 104

# %% [markdown]
# ### What is the maximum & minimum 'average_price' per year in england ?

# %%
df1=data[data["area"]=="england"]

# %%
df1
# Out:
#             date     ID     area  average_price       code  houses_sold  \
# 13248 1995-01-01  13248  england          53203  E92000001      47639.0
# 13249 1995-02-01  13249  england          53096  E92000001      47880.0
# 13250 1995-03-01  13250  england          53201  E92000001      67025.0
# 13251 1995-04-01  13251  england          53591  E92000001      56925.0
# 13252 1995-05-01  13252  england          53678  E92000001      64192.0
# ...          ...    ...      ...            ...        ...          ...
# 13544 2019-09-01  13544  england         249942  E92000001      64605.0
# 13545 2019-10-01  13545  england         249376  E92000001      68677.0
# 13546 2019-11-01  13546  england         248515  E92000001      67814.0
# 13547 2019-12-01  13547  england         250410  E92000001          NaN
# 13548 2020-01-01  13548  england         247355  E92000001          NaN
#
#        no_of_crimes  Year  Month
# 13248           NaN  1995      1
# 13249           NaN  1995      2
# 13250           NaN  1995      3
# 13251           NaN  1995      4
# 13252           NaN  1995      5
# ...             ...   ...    ...
# 13544           NaN  2019      9
# 13545           NaN  2019     10
# 13546           NaN  2019     11
# 13547           NaN  2019     12
# 13548           NaN  2020      1
#
# [301 rows x 9 columns]

# %%
df1.groupby("Year")["average_price"].min()
# Out:
# Year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %%
df1.groupby("Year")["average_price"].max()
# Out:
# Year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %% [markdown]
# ### What is the Maximum & Minimum No. of Crimes recorded per area ?

# %%
data.head(5)
# Out:
#         date  ID            area  average_price       code  houses_sold  \
# 0 1995-01-01   0  city of london          91449  E09000001         17.0
# 1 1995-02-01   1  city of london          82203  E09000001          7.0
# 2 1995-03-01   2  city of london          79121  E09000001         14.0
# 3 1995-04-01   3  city of london          77101  E09000001          7.0
# 4 1995-05-01   4  city of london          84409  E09000001         10.0
#
#    no_of_crimes  Year  Month
# 0           NaN  1995      1
# 1           NaN  1995      2
# 2           NaN  1995      3
# 3           NaN  1995      4
# 4           NaN  1995      5

# %%
df2=data.groupby("area")["no_of_crimes"].min().sort_values(ascending=False)

# %%
df2
# Out:
# area
# westminster               3504.0
# lambeth                   2381.0
# southwark                 2267.0
# newham                    2130.0
# camden                    2079.0
# croydon                   2031.0
# islington                 1871.0
# ealing                    1871.0
# hackney                   1870.0
# brent                     1850.0
# barnet                    1703.0
# lewisham                  1675.0
# tower hamlets             1646.0
# enfield                   1635.0
# wandsworth                1582.0
# waltham forest            1575.0
# haringey                  1536.0
# hounslow                  1529.0
# greenwich                 1513.0
# redbridge                 1487.0
# hillingdon                1445.0
# bromley                   1441.0
# kensington and chelsea    1347.0
# hammersmith and fulham    1323.0
# barking and dagenham      1217.0
# havering                  1130.0
# harrow                     937.0
# bexley                     860.0
# merton                     819.0
# sutton                     787.0
# richmond upon thames       700.0
# kingston upon thames       692.0
# city of london               0.0
# east midlands                NaN
# east of england              NaN
# england                      NaN
# inner london                 NaN
# london                       NaN
# north east                   NaN
# north west                   NaN
# outer london                 NaN
# south east                   NaN
# south west                   NaN
# west midlands                NaN
# yorks and the humber         NaN
# Name: no_of_crimes, dtype: float64

# %% [markdown]
# ### Show the total count of records of each area, where average price is less than 100000.

# %%
data.head(5)
# Out:
#         date  ID            area  average_price       code  houses_sold  \
# 0 1995-01-01   0  city of london          91449  E09000001         17.0
# 1 1995-02-01   1  city of london          82203  E09000001          7.0
# 2 1995-03-01   2  city of london          79121  E09000001         14.0
# 3 1995-04-01   3  city of london          77101  E09000001          7.0
# 4 1995-05-01   4  city of london          84409  E09000001         10.0
#
#    no_of_crimes  Year  Month
# 0           NaN  1995      1
# 1           NaN  1995      2
# 2           NaN  1995      3
# 3           NaN  1995      4
# 4           NaN  1995      5

# %%
df3=data[data["average_price"] < 100000]

# %%
df3
# Out:
#             date     ID            area  average_price       code  \
# 0     1995-01-01      0  city of london          91449  E09000001
# 1     1995-02-01      1  city of london          82203  E09000001
# 2     1995-03-01      2  city of london          79121  E09000001
# 3     1995-04-01      3  city of london          77101  E09000001
# 4     1995-05-01      4  city of london          84409  E09000001
# ...          ...    ...             ...            ...        ...
# 13330 2001-11-01  13330         england          95083  E92000001
# 13331 2001-12-01  13331         england          95992  E92000001
# 13332 2002-01-01  13332         england          96215  E92000001
# 13333 2002-02-01  13333         england          96676  E92000001
# 13334 2002-03-01  13334         england          98962  E92000001
#
#        houses_sold  no_of_crimes  Year  Month
# 0             17.0           NaN  1995      1
# 1              7.0           NaN  1995      2
# 2             14.0           NaN  1995      3
# 3              7.0           NaN  1995      4
# 4             10.0           NaN  1995      5
# ...            ...           ...   ...    ...
# 13330     109149.0           NaN  2001     11
# 13331      93329.0           NaN  2001     12
# 13332      71678.0           NaN  2002      1
# 13333      77131.0           NaN  2002      2
# 13334     102828.0           NaN  2002      3
#
# [2209 rows x 9 columns]

# %%
df3.groupby("area")["average_price"].count().sort_values(ascending=False)
# Out:
# area
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# waltham forest           64
# bexley                   64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# bromley                  33
# haringey                 33
# ealing                   31
# inner london             31
# kingston upon thames     30
# harrow                   30
# wandsworth               26
# barnet                   25
# islington                19
# city of london           11
# Name: average_price, dtype: int64

# %%
df3["area"].value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ealing                   31
# kingston upon thames     30
# harrow                   30
# wandsworth               26
# barnet                   25
# islington                19
# city of london           11
# Name: area, dtype: int64
