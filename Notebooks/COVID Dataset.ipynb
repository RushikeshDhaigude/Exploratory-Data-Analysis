# %% [markdown]
# ## COVID Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Shree\Desktop\DS PROJECTS\4. covid_19_data.csv")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# ### Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
data.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
# sns.heatmap(df.isnull()) - It will show the all columns & missing values in them in heat map form.

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
data.groupby("Region").sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby("Region").sum().head(5)
# Out:
#              Confirmed  Deaths  Recovered
# Region
# Afghanistan       1939      60        252
# Albania            766      30        455
# Algeria           3848     444       1702
# Andorra            743      42        423
# Angola              27       2          7

# %%
data.groupby("Region")["Confirmed"].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %%
## df.sort_values(by= ['Col_name'] ) - Sort the entire dataframe by the values of the given column.

# %%
data.sort_values(by=["Deaths"])      # BY default sort the values in ascending order
# Out:
#           Date                  State            Region  Confirmed  Deaths  \
# 126  4/29/2020                    NaN  Papua New Guinea          8       0
# 279  4/29/2020   Prince Edward Island            Canada         27       0
# 135  4/29/2020                    NaN            Rwanda        225       0
# 272  4/29/2020  Northwest Territories            Canada          5       0
# 271  4/29/2020     Northern Territory         Australia         28       0
# ..         ...                    ...               ...        ...     ...
# 265  4/29/2020               New York                US     299691   23477
# 57   4/29/2020                    NaN            France     165093   24087
# 153  4/29/2020                    NaN             Spain     236899   24275
# 168  4/29/2020                    NaN                UK     165221   26097
# 80   4/29/2020                    NaN             Italy     203591   27682
#
#      Recovered
# 126          0
# 279          0
# 135         98
# ...

# %%
data.sort_values(by=["Deaths"],ascending=False)
# Out:
#           Date          State  Region  Confirmed  Deaths  Recovered
# 80   4/29/2020            NaN   Italy     203591   27682      71252
# 168  4/29/2020            NaN      UK     165221   26097          0
# 153  4/29/2020            NaN   Spain     236899   24275     132929
# 57   4/29/2020            NaN  France     165093   24087      48228
# 265  4/29/2020       New York      US     299691   23477          0
# ..         ...            ...     ...        ...     ...        ...
# 55   4/29/2020            NaN    Fiji         18       0         12
# 284  4/29/2020      Recovered  Canada          0       0      20327
# 285  4/29/2020      Recovered      US          0       0     120720
# 286  4/29/2020        Reunion  France        420       0        300
# 259  4/29/2020  New Brunswick  Canada        118       0          0
#
# [321 rows x 6 columns]

# %%
data.groupby("Region")["Confirmed"].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
# Groupby on more than 1 column

# %%
df1=data.groupby("Region")["Confirmed","Deaths"].sum()
# Out:
# C:\Users\Shree\AppData\Local\Temp\ipykernel_8776\156237952.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1=data.groupby("Region")["Confirmed","Deaths"].sum()

# %%
df1
# Out:
#                     Confirmed  Deaths
# Region
# Afghanistan              1939      60
# Albania                   766      30
# Algeria                  3848     444
# Andorra                   743      42
# Angola                     27       2
# ...                       ...     ...
# West Bank and Gaza        344       2
# Western Sahara              6       0
# Yemen                       6       0
# Zambia                     97       3
# Zimbabwe                   32       4
#
# [187 rows x 2 columns]

# %% [markdown]
# ### Remove all the records where the Confirmed Cases is Less Than 10.

# %%
less_10=data[data["Confirmed"] < 10]

# %%
less_10
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
# use ~ sign to remove the records from dataframe
# df.[~(df["column"])]

# %%
data[~(data["Confirmed"] < 10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# ### In which Region, maximum number of Confirmed cases were recorded ?

# %%
data.groupby("Region")["Confirmed"].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %% [markdown]
# ### In which Region, minimum number of Deaths cases were recorded ?

# %%
data.groupby("Region")["Deaths"].sum().sort_values()
# Out:
# Region
# Laos              0
# Mongolia          0
# Mozambique        0
# Cambodia          0
# Fiji              0
#               ...
# France        24121
# Spain         24275
# UK            26166
# Italy         27682
# US            60967
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# ### How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?

# %%
data[data["Region"]=="India"]
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
data[data["Region"]=="US"].head(10)
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
#
#      Recovered
# 181          0
# 182          0
# 186          0
# 187          0
# 195          0
# 199          0
# 200          0
# 202          0
# 204          0
# 205          0

# %% [markdown]
# ### Sort the entire data wrt No. of Confirmed cases in ascending order.

# %%
data.sort_values( by = "Confirmed", ascending = True)
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %% [markdown]
# ### Sort the entire data wrt No. of Recovered cases in descending order.

# %%
data.sort_values( by = "Recovered", ascending = False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]
